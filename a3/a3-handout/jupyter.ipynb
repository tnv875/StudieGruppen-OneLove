# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('20000records.tsv', sep='\t', header=0)

# %%
df
# Out:
#                            name  \
# 0                        France
# 1      United States of America
# 2                       Germany
# 3                         Italy
# 4                         Japan
# ...                         ...
# 19994                   Nucetto
# 19995                  Tréduder
# 19996                   Salmour
# 19997              Vrigne-Meuse
# 19998           Pierre-Perthuis
#
#                                        alternative_names  osm_type   osm_id  \
# 0      ꃔꇩ,프랑스,フランス,ፈረንሣይ,ፈረንሳይ,បារាំង,ଫ୍ରାନ୍ସ,ފަރަންސ...  relation  2202162
# 1      미국,ᐊᒥᐊᓕᑲ,އެމެރިކާ,የተባበሩት የአሜሪካ ግዛቶች,สหรัฐอเมริ...  relation   148838
# 2      독일,ᔮᒪᓂ,ドイツ,ጀርመን,ଜର୍ମାନୀ,ޖަރުމަނުވިލާތް,អាល្លឺម...  relation    51477
# 3      ᐃᑕᓖ,ጣልያን,イタリア,이탈리아,ଇଟାଲୀ,ອິຕາລີ,អ៊ីតាលី,އިޓަލީ...  relation   365331
# 4      일본,ጃፓን,ޖަޕާނު,ᓃᑉᐊᓐ,ଜାପାନ,ជប៉ុន,ປະເທດຍີ່ປຸ່ນ,ปร...  relation   382313
# ...                                                  ...       ...      ...
# ...
